# %% [markdown]
# <a href="https://colab.research.google.com/github/minikouda/pyramyd_ml/blob/main/Shizhe_Zhang_P_ML_TEAM_WORKSPACE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# PYRAMYD ML Team workspace.

# %%
#6 7

# %%
# fjfsjfsljflsf

# %%
print('hello world')
# Out:
# hello
